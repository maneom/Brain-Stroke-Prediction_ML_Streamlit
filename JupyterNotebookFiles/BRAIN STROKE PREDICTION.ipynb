# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING DATA

# %%
df = pd.read_csv('full_data.csv')

# %%
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             4981 non-null   object
#  1   age                4981 non-null   float64
#  2   hypertension       4981 non-null   int64
#  3   heart_disease      4981 non-null   int64
#  4   ever_married       4981 non-null   object
#  5   work_type          4981 non-null   object
#  6   Residence_type     4981 non-null   object
#  7   avg_glucose_level  4981 non-null   float64
#  8   bmi                4981 non-null   float64
#  9   smoking_status     4981 non-null   object
#  10  stroke             4981 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 428.2+ KB

# %%
# THERE ARE NO DUPLICATE VALUES IN DATASET
df.duplicated().sum()
# Out:
# 0

# %%
# DIFFERENT TYPES OF CATEGORIES IN WORK MENTIONED
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children'], dtype=object)

# %%
# DIFFERENT TYPES OF CATEGORIES IN RESIDENCE MENTIONED
df['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
# DIFFERENT TYPES OF CATEGORIES IN SMOKING STATUS MENTIONED
df['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  4981.000000   4981.000000    4981.000000        4981.000000
# mean     43.419859      0.096165       0.055210         105.943562
# std      22.662755      0.294848       0.228412          45.075373
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.230000
# 50%      45.000000      0.000000       0.000000          91.850000
# 75%      61.000000      0.000000       0.000000         113.860000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4981.000000  4981.000000
# mean     28.498173     0.049789
# std       6.790464     0.217531
# min      14.000000     0.000000
# 25%      23.700000     0.000000
# 50%      28.100000     0.000000
# 75%      32.600000     0.000000
# max      48.900000     1.000000

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.head(2)
# Out:
#   gender   age  hypertension  heart_disease ever_married work_type  \
# 0   Male  67.0             0              1          Yes   Private
# 1   Male  80.0             0              1          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1

# %%
sns.countplot(data=df, x=df['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# IN OUR DATA THERE ARE FEMALE'S MORE THAN MALE

# %%
sns.countplot(x=df['stroke'])
plt.show()

# %% [markdown]
# OUR DATA IS VERY MUCH IMBALANCED THERE MANY VALUES VALUS FOR STROKE = 0

# %%
sns.boxplot(data=df)
plt.xticks(rotation="vertical")
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'age'),
#   Text(1, 0, 'hypertension'),
#   Text(2, 0, 'heart_disease'),
#   Text(3, 0, 'avg_glucose_level'),
#   Text(4, 0, 'bmi'),
#   Text(5, 0, 'stroke')])

# %%
df[df['avg_glucose_level']>150]
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# 11    Female  79.0             0              1          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4968  Female  78.0             1              1          Yes        Private
# 4970  Female  70.0             0              1          Yes  Self-employed
# 4972    Male  72.0             0              1          Yes        Private
# 4975    Male  31.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
#
# ...

# %% [markdown]
# IN OUR DATA THERE ARE MUCH EXTREME VALUES BUT FOR AVERAGE BODY MASS INDEX, CURRENTLY I AM KEEPING THEM AS IT IS

# %%
sns.scatterplot(data=df, y='age', x='bmi', hue='stroke')
# Out:
# <Axes: xlabel='bmi', ylabel='age'>

# %% [markdown]
# FROM ABOVE SCATTER PLOT IT CAN EASILY SEEN TO HAVE MUCH NUMBER OF NON-STOKE PEOPLES

# %% [markdown]
# # ONE HOT ENCODING

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
import pickle

# %%
# CURRENT DATASET HAVE 5 CATEGORICAL COLUMNS. I AM GOING TO USE ONE HOT ENCODER TO CONVERT THEM TO NUMERIC VALUES

transformer = ColumnTransformer(transformers=[
    ('ohe', OneHotEncoder(dtype=int, drop='first'),['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status'])
], remainder='passthrough')
X = transformer.fit_transform(df.drop('stroke', axis=1))
y = df['stroke']

# %%
pickle.dump(transformer,open("transformer.pkl", "wb"))

# %% [markdown]
# # OVERSAMPLING

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # MODEL CREATION

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_predict = rfc.predict(X_test)
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1567
#            1       0.99      0.94      0.97      1557
#
#     accuracy                           0.97      3124
#    macro avg       0.97      0.97      0.97      3124
# weighted avg       0.97      0.97      0.97      3124

# %%
pickle.dump(rfc,open("RandomForestClassifier.pkl", "wb"))

# %% [markdown]
# # PREDICTION

# %%
import pickle
import pandas as pd
transformer = pickle.load(open("transformer.pkl", "rb"))
rfc = pickle.load(open("RandomForestClassifier.pkl", "rb"))
col = ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married','work_type', 'Residence_type', 'avg_glucose_level', 'bmi','smoking_status']

# %%
input = transformer.transform(pd.DataFrame([['Male',96.0, 0, 1, 'Yes', 	'Private', 	'Rural' ,	228.69 ,	50.6 ,	'smokes']],
                                   columns=col
                                  ))
print("Output = ",rfc.predict(input)[0])
# Out:
# Output =  0

# %%
input = transformer.transform(pd.DataFrame([['Female',75.0, 1, 1, 'Yes', 	'Private', 	'Urban' ,	533.2 ,	40 ,	'Unknown']],
                                   columns=col
                                  ))
print("Output = ",rfc.predict(input)[0])
# Out:
# Output =  1
